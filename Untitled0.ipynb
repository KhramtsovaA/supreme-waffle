# %% [markdown]
# <a href="https://colab.research.google.com/github/KhramtsovaA/supreme-waffle/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('sample_data/california_housing_train.csv')

# %%
df.head(n=10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# ...

# %%
df.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0

# %%
df.shape
# Out:
# (17000, 9)

# %%
df.isnull()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 16995      False     False               False        False           False
# 16996      False     False               False        False           False
# 16997      False     False               False        False           False
# 16998      False     False               False        False           False
# 16999      False     False               False        False           False
#
# ...

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
df[['latitude', 'population']]
# Out:
#        latitude  population
# 0         34.19      1015.0
# 1         34.40      1129.0
# 2         33.69       333.0
# 3         33.64       515.0
# 4         33.57       624.0
# ...         ...         ...
# 16995     40.58       907.0
# 16996     40.69      1194.0
# 16997     41.84      1244.0
# 16998     41.80      1298.0
# 16999     40.54       806.0
#
# [17000 rows x 2 columns]

# %%
df[(df['housing_median_age'] > 20) & (df['total_rooms'] > 2000)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6        -114.58     33.61                25.0       2907.0           680.0
# 8        -114.59     33.61                34.0       4789.0          1175.0
# 13       -114.61     34.83                31.0       2478.0           464.0
# 42       -115.49     32.67                25.0       2322.0           573.0
# 45       -115.50     32.67                35.0       2159.0           492.0
# ...          ...       ...                 ...          ...             ...
# 16986    -124.19     40.73                21.0       5694.0          1056.0
# 16990    -124.22     41.73                28.0       3003.0           699.0
# 16993    -124.23     40.54                52.0       2694.0           453.0
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
#
# ...

# %%
print(df['population'].max())
# Out:
# 35682.0

# %%
df[['population', 'total_rooms']].median()
# Out:
# population     1167.0
# total_rooms    2127.0
# dtype: float64

# %%
print(df['population'].sum())
# Out:
# 24302757.0

# %%
df[df['housing_median_age'] < 20] ['total_bedrooms'], ['total_rooms']
# Out:
# (0        1283.0
#  1        1901.0
#  2         174.0
#  3         337.0
#  10        801.0
#            ...
#  16983     714.0
#  16987     722.0
#  16991     616.0
#  16997     531.0
#  16998     552.0
#  Name: total_bedrooms, Length: 4826, dtype: float64,
#  ['total_rooms'])

# %%
df[['population', 'total_rooms']].median()
# Out:
# population     1167.0
# total_rooms    2127.0
# dtype: float64

# %%
import seaborn as sns

# %%
sns.scatterplot(data=df, x="longitude", y="latitude")
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
sns.scatterplot(data=df, x="households", y="population", hue="total_rooms")
# Out:
# <Axes: xlabel='households', ylabel='population'>
